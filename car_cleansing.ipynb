# %% [markdown]
# # Introduction
#
# This notebook provides a replicate of my work as a research assistant at Trinity College. I'll replicate some of the data cleansing part here.
#
# Paper: *Product Differentiation in the Automobiles Market: An Empirical Analysis* (Rasha Ahmed and Mark Stater) <br>
# Research Assistant: My Phung

# %% [markdown]
# ## Part 1: Load and cleanse data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.linear_model import LogisticRegression 

# %matplotlib inline

# %%
data = pd.read_excel('car_data.xlsx')

# %%
data.shape
# Out:
# (7896, 58)

# %%
data.head(10)
# Out:
#     Year     Mft  Mtf# Segment  Segment#        Make and Series  \
# 0  2005.0  Acura   1.0     LUX       4.0                NSX 3.0
# 1  2005.0  Acura   1.0     LUX       4.0                NSX 3.2
# 2  2005.0  Acura   1.0     LUX       4.0                  3.5RL
# 3  2005.0  Acura   1.0     LUX       4.0                    RSX
# 4  2005.0  Acura   1.0     LUX       4.0             RSX Type-S
# 5  2005.0  Acura   1.0     LUX       4.0                  3.2TL
# 6  2005.0  Acura   1.0     MID       2.0                    TSX
# 7  2005.0  Audi   18.0     LUX       4.0               A4 1.8T
# 8  2005.0  Audi   18.0     LUX       4.0        A4 1.8T Quattro
# 9  2005.0  Audi   18.0     LUX       4.0  A4 1.8T Avant Quattro
#
#    BODYno. of dr BODY Style  body_typenum Drive type  ...  traction cont  \
# 0            2.0      coupe           4.0        RWD  ...              S
# 1            2.0      coupe           4.0        RWD  ...              S
# 2            4.0      sedan           1.0        AWD  ...             --
# 3            2.0      coupe           4.0        FWD  ...             --
# 4            2.0      coupe           4.0        FWD  ...             --
# 5            4.0      sedan           1.0        FWD  ...             --
# 6            2.0      coupe           4.0        FWD  ...             --
# 7            4.0      sedan           1.0        FWD  ...             --
# 8            4.0      sedan           1.0        AWD  ...             --
# 9            4.0      wagon           3.0        AWD  ...             --
#
#   Stability cont 4-Whl. ABS AVG MPG E85 Fuel comp Retail P Guzzler Tax  \
# 0             --          S   20.15           NaN    89765          --
# 1             --          S   20.15           NaN    89765          --
# 2              S          S   21.60           NaN    49470          --
# 3             --          S   30.15           NaN    20745          --
# 4             --          S   27.15           NaN    24140          --
# 5              S          S   24.50           NaN    33470          --
# 6              S          S   24.60           NaN    27060          --
# 7              S          S   26.05           NaN    26520          --
# 8              S          S   25.05           NaN    28870          --
# 9              S          S   24.60           NaN    29870          --
#
#   MPG CITY MPG HWY  AVG_MPG
# 0       17      24    20.15
# 1       17      24    20.15
# 2       18      26    21.60
# 3       27      34    30.15
# 4       24      31    27.15
# 5       20      30    24.50
# 6       21      29    24.60
# 7       22      31    26.05
# 8       21      30    25.05
# 9       21      29    24.60
#
# [10 rows x 58 columns]

# %%
data.columns.tolist()
# Out:
# ['Year ',
#  'Mft',
#  'Mtf#',
#  'Segment',
#  'Segment#',
#  'Make and Series',
#  'BODYno. of dr',
#  'BODY Style',
#  'Unnamed: 8',
#  'Drive type',
#  'Drive Type #',
#  'Wheel base',
#  'Trach(Front)',
#  'Track (rear)',
#  'Length',
#  'Width',
#  'Height',
#  'Curb Weight',
#  'Engine Type',
#  'E. Type#',
#  'Cylinder',
#  'Cylinder #',
#  'Unnamed: 22',
#  'CID',
#  'Size CC',
#  'Liter',
#  'Valves/ cyl',
#  'Fuel Sys. Inj',
#  'FS Inj #',
#  'Fuel Sys. Intake',
#  'Fuel Sys. Intake #',
#  'mpg Fuel Type',
#  'mpg Fuel Type #',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Bore& stroke ins',
#  '...x...',
#  'mm',
#  '...x....1',
#  'Comp.ratio',
#  'HP',
#  'RPM',
#  'Torque(lb.ft)',
#  'torque...',
#  'torque(nm)',
#  'Torque RPM',
#  'Manual/Auto/Transmission Std',
#  'Manual/Auto/Transmission ',
#  'Transmission #',
#  'Speed',
#  'Opt.',
#  'traction cont',
#  'Stability cont',
#  '4-Whl. ABS',
#  'AVG MPG',
#  'E85 Fuel comp',
#  'Retail P',
#  'Guzzler Tax',
#  'Unnamed: 58',
#  'MPG CITY',
#  'MPG HWY',
#  'Unnamed: 61']

# %%
#Check all the 'Unnamed' columns
unnamed_col = ['Unnamed: 8','Unnamed: 22','Unnamed: 33','Unnamed: 34','Unnamed: 58', 'Unnamed: 61']
data[unnamed_col]
# Out:
#       Unnamed: 8 Unnamed: 22 Unnamed: 33 Unnamed: 34  Unnamed: 58  Unnamed: 61
# 0            4.0         NaN         NaN         NaN          NaN        20.15
# 1            4.0         NaN         NaN         NaN          NaN        20.15
# 2            1.0         NaN         NaN         NaN          NaN        21.60
# 3            4.0         NaN         NaN         NaN          NaN        30.15
# 4            4.0         NaN         NaN         NaN          NaN        27.15
# ...          ...         ...         ...         ...          ...          ...
# 7891         1.0         NaN           G        None          NaN        23.05
# 7892         1.0         NaN           G        None          NaN        23.05
# 7893         1.0         NaN           G        None          NaN        21.15
# 7894         1.0         NaN           G        None          NaN        21.15
# 7895         1.0         NaN           G        None          NaN        21.15
#
# [7896 rows x 6 columns]

# %% [markdown]
# When comparing these numbers with the original excel file, I figured column 8th represents the body types (as numerical - categorical data) and column 61st means average mile-per-gallon (calculated by taking the average of MPG Highway and MPG City).
# Other columns have too many missing values so they will be skipped for this analysis.

# %%
data = data.rename(columns={'Unnamed: 8': 'body_typenum', 'Unnamed: 61': 'AVG_MPG'})
data = data.drop(columns= ['Unnamed: 22','Unnamed: 33','Unnamed: 34','Unnamed: 58'])

# %%
#Check data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7896 entries, 0 to 7895
# Data columns (total 58 columns):
# Year                            7894 non-null float64
# Mft                             7894 non-null object
# Mtf#                            7895 non-null float64
# Segment                         7872 non-null object
# Segment#                        7727 non-null float64
# Make and Series                 7847 non-null object
# BODYno. of dr                   6688 non-null float64
# BODY Style                      6646 non-null object
# body_typenum                    6633 non-null float64
# Drive type                      6883 non-null object
# Drive Type #                    6691 non-null float64
# Wheel base                      6883 non-null object
# Trach(Front)                    854 non-null object
# Track (rear)                    853 non-null object
# Length                          6881 non-null object
# Width                           6881 non-null object
# Height                          6875 non-null object
# Curb Weight                     6632 non-null object
# Engine Type                     6693 non-null object
# E. Type#                        6685 non-null float64
# Cylinder                        6656 non-null object
# Cylinder #                      6656 non-null float64
# CID                             5828 non-null object
# Size CC                         6692 non-null object
# Liter                           6684 non-null float64
# Valves/ cyl                     6686 non-null object
# Fuel Sys. Inj                   6680 non-null object
# FS Inj #                        6684 non-null float64
# Fuel Sys. Intake                6686 non-null object
# Fuel Sys. Intake #              6683 non-null float64
# mpg Fuel Type                   6697 non-null object
# mpg Fuel Type #                 6697 non-null float64
# Bore& stroke ins                5933 non-null object
# ...x...                         5771 non-null float64
# mm                              6794 non-null object
# ...x....1                       6624 non-null object
# Comp.ratio                      6793 non-null object
# HP                              6823 non-null object
# RPM                             6721 non-null float64
# Torque(lb.ft)                   5947 non-null object
# torque...                       539 non-null object
# torque(nm)                      6852 non-null object
# Torque RPM                      6718 non-null float64
# Manual/Auto/Transmission Std    6878 non-null object
# Manual/Auto/Transmission        6482 non-null object
# Transmission #                  6295 non-null float64
# Speed                           6482 non-null object
# Opt.                            6865 non-null object
# traction cont                   5092 non-null object
# Stability cont                  6881 non-null object
# 4-Whl. ABS                      6881 non-null object
# AVG MPG                         7626 non-null float64
# E85 Fuel comp                   603 non-null object
# Retail P                        6739 non-null object
# Guzzler Tax                     6831 non-null object
# MPG CITY                        6874 non-null object
# MPG HWY                         6675 non-null object
# AVG_MPG                         7661 non-null float64
# dtypes: float64(18), object(40)
# memory usage: 3.5+ MB

# %%
data['Guzzler Tax']
# Out:
# 0       --
# 1       --
# 2       --
# 3       --
# 4       --
#         ..
# 7891    --
# 7892    --
# 7893    --
# 7894    --
# 7895    --
# Name: Guzzler Tax, Length: 7896, dtype: object

# %%
#Define a function to get the summary of all data.

def getDfSummary(input_data):
    output_data=input_data.describe() 
    output_data.loc['number_distinct'] = input_data.nunique() 
    output_data.loc['number_nan'] = input_data.isna().sum()
    output_data=output_data.T
    return output_data

getDfSummary(data)
# Out:
#                      count         mean          std     min      25%  \
# Year                7894.0  2010.231948     2.848431  2005.0  2008.00
# Mtf#                7895.0     8.265104     6.464086     1.0     2.00
# Segment#            7727.0     2.592856     1.259555     1.0     1.00
# BODYno. of dr       6688.0     3.366776     0.930620     2.0     2.00
# body_typenum        6633.0     2.250415     1.540519     1.0     1.00
# Drive Type #        6691.0     2.114931     0.710020     1.0     2.00
# E. Type#            6685.0     1.263725     0.591943     1.0     1.00
# Cylinder #          6656.0     9.430739     4.991805     1.0     5.00
# Liter               6684.0     3.146933     1.311867     1.0     2.00
# FS Inj #            6684.0     5.725613     2.154957     1.0     3.00
# Fuel Sys. Intake #  6683.0     1.701781     1.406821     1.0     1.00
# mpg Fuel Type #     6697.0     5.005525     0.322586     1.0     5.00
# ...x...             5771.0     3.458023     0.268899     2.4     3.27
# RPM                 6721.0  5969.449487   751.742630     0.0  5600.00
# Torque RPM          6718.0  3715.824948  1191.332958     0.0  2800.00
# Transmission #      6295.0     1.937252     1.000017     1.0     1.00
# AVG MPG             7626.0    21.034753     9.949105     0.0    19.15
# AVG_MPG             7661.0    21.080335     9.989058     0.0    19.15
#
#                         50%      75%      max  number_distinct  number_nan
# Year                2011.00  2013.00  2014.00             10.0         2.0
# Mtf#                   6.00    13.00    23.00             21.0         1.0
# Segment#               2.00     4.00     4.00              4.0       169.0
# BODYno. of dr          4.00     4.00     5.00              3.0      1208.0
# body_typenum           1.00     4.00     6.00              6.0      1263.0
# Drive Type #           2.00     3.00     3.00              3.0      1205.0
# E. Type#               1.00     1.00     6.00              6.0      1211.0
# Cylinder #             7.00    14.00    18.00             18.0      1240.0
# Liter                  3.00     3.70     8.40             57.0      1212.0
# FS Inj #               7.00     7.00     8.00              8.0      1212.0
# Fuel Sys. Intake #     1.00     1.00     5.00              5.0      1213.0
# mpg Fuel Type #        5.00     5.00     7.00              7.0      1199.0
# ...x...                3.46     3.65     4.17             85.0      2125.0
# RPM                 6000.00  6400.00  8700.00             67.0      1175.0
# Torque RPM          4000.00  4500.00  8000.00             79.0      1178.0
# Transmission #         1.00     3.00     5.00              5.0      1601.0
# AVG MPG               22.50    26.05   113.85            257.0       270.0
# AVG_MPG               22.50    26.05   113.85            255.0       235.0

# %% [markdown]
# The data contains both continuous and categorical data and has a lot of missing values. Some columns are not presented, which tells me that they either have alphabetical data or are supposed to have all numerical data but may contain improper data type (like 'N/A', 'NA', etc). I'll need to fix them.
#
# Next, I will fill in the missing values with the mean value if the columns contain continuous values. If it's a categorical data, I will have to leave them out for now since we have a good amount of data.

# %%
#Define a function that would do a quick check of data types that might go wrong
#All alpha-type columns
alpha_cols = ['Mft', 'Segment','Make and Series','BODY Style','Drive type','Engine Type','Cylinder','Fuel Sys. Inj','mpg Fuel Type',
             'Manual/Auto/Transmission Std','Manual/Auto/Transmission ','Opt.','traction cont','Stability cont','4-Whl. ABS','E85 Fuel comp',
             'Guzzler Tax']


#Check columns that are not all numerical
def check_digit(data):
    colnames = data.columns.tolist()
    colnames = [i for i in colnames if i not in alpha_cols]
    num_cols = []
    non_num_cols = []
    for i in colnames:
        count_num = data[i].apply(lambda x: str(x).strip().isdigit()).nunique()
        if count_num == 1:
            num_cols.append(i)
        else:
            non_num_cols.append(i)    
    return num_cols, non_num_cols

# %%
#Fill in missing values with mean values
cols_needfix = check_digit(data)[1]
data[cols_needfix] = data[cols_needfix].fillna(data[cols_needfix].mean())

getDfSummary(data[cols_needfix])
# Out:
#                  count unique    top  freq number_distinct number_nan
# Wheel base        6883    178  106.3   235             178       1013
# Trach(Front)       854     74     63    68              74       7042
# Track (rear)       853     82     62    61              82       7043
# Length            6881    389     --   190             389       1015
# Width             6881    142   71.7   229             142       1015
# Height            6875    146   57.9   327             146       1021
# Curb Weight       6632   1315     --   197            1315       1264
# CID               5828    165    122   401             165       2068
# Size CC           6692    235   1998   254             235       1204
# Valves/ cyl       6686      6      4  5895               6       1210
# Bore& stroke ins  5933     83    3.5   443              83       1963
# mm                6794    103     86   429             103       1102
# ...x....1         6624    118     86   458             118       1272
# Comp.ratio        6793     99     10   844              99       1103
# HP                6823    304    300   209             304       1073
# Torque(lb.ft)     5947    288    258   169             288       1949
# torque...          539     68   4000   123              68       7357
# torque(nm)        6852    333    350   179             333       1044
# Speed             6482      9      6  3048               9       1414
# Retail P          6739   4420     --   386            4420       1157
# MPG CITY          6874     73     18   779              73       1022
# MPG HWY           6675     61     25   661              61       1221

# %% [markdown]
# Fillna does not solve the problem in this case since the missing values are not just missing, they may contain non-digit data. To check this, I need to check all the unique values in each column.

# %%
# [17 18 27 24 20 21 22 '18' 15 19 16 25 34 23 12 26 13 30 36 32 46 48 61 57
#  29 11 28 14 31 10 35 60 38 58 '24' '13' '--' 50 '23' nan 37 49 33 40 9 42
#  '22' '19' '21' '17' '12' '16' '14' '15' '20' ' ' 41 51 90 43 92 44 126
#  '106' 39 '98e' '25' '52e' 47 53 '95e' '82e' '108e' 45]
# [24 26 34 31 30 29 28 27 25 23 21 35 33 32 20 37 44 38 51 47 68 56 17 16
#  22 19 18 36 41 42 46 43 '32' '21' nan 50 66 '31' 39 40 15 '33' '26' 45
#  '28' '30' '25' '19' '20' '23' '22' 48 95 '24' '17' 106 107 '34' 99 '92'
#  '27' '92e']

# %% [markdown]
# Convert all non-digit values to null values.

# %%
def convert_digit(digit_data):
    colnames = digit_data.columns.tolist()
    for i in colnames:
        digit_data[i] = digit_data[i].apply(lambda x: None if str(x).isalpha() == True else x)
    return digit_data

# %%
#data_digit = data[cols_needfix].astype(float)
data_digitclean = convert_digit(data[cols_needfix])
getDfSummary(data_digitclean)
# Out:
# C:\Users\emmyp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                  count unique    top  freq number_distinct number_nan
# Wheel base        6883    178  106.3   235             178       1013
# Trach(Front)       854     74     63    68              74       7042
# Track (rear)       853     82     62    61              82       7043
# Length            6881    389     --   190             389       1015
# Width             6881    142   71.7   229             142       1015
# Height            6875    146   57.9   327             146       1021
# Curb Weight       6632   1315     --   197            1315       1264
# CID               5828    165    122   401             165       2068
# Size CC           6692    235   1998   254             235       1204
# Valves/ cyl       6686      6      4  5895               6       1210
# Bore& stroke ins  5933     83    3.5   443              83       1963
# mm                6794    103     86   429             103       1102
# ...x....1         6624    118     86   458             118       1272
# Comp.ratio        6793     99     10   844              99       1103
# HP                6823    304    300   209             304       1073
# Torque(lb.ft)     5947    288    258   169             288       1949
# torque...          539     68   4000   123              68       7357
# torque(nm)        6852    333    350   179             333       1044
# Speed             6476      8      6  3048               8       1420
# Retail P          6739   4420     --   386            4420       1157
# MPG CITY          6874     73     18   779              73       1022
# MPG HWY           6675     61     25   661              61       1221

# %%
data_digitclean = data_digitclean.fillna(data_digitclean.mean())
getDfSummary(data_digitclean)
# Out:
#                  count unique    top  freq number_distinct number_nan
# Wheel base        6883    178  106.3   235             178       1013
# Trach(Front)       854     74     63    68              74       7042
# Track (rear)       853     82     62    61              82       7043
# Length            6881    389     --   190             389       1015
# Width             6881    142   71.7   229             142       1015
# Height            6875    146   57.9   327             146       1021
# Curb Weight       6632   1315     --   197            1315       1264
# CID               5828    165    122   401             165       2068
# Size CC           6692    235   1998   254             235       1204
# Valves/ cyl       6686      6      4  5895               6       1210
# Bore& stroke ins  5933     83    3.5   443              83       1963
# mm                6794    103     86   429             103       1102
# ...x....1         6624    118     86   458             118       1272
# Comp.ratio        6793     99     10   844              99       1103
# HP                6823    304    300   209             304       1073
# Torque(lb.ft)     5947    288    258   169             288       1949
# torque...          539     68   4000   123              68       7357
# torque(nm)        6852    333    350   179             333       1044
# Speed             6476      8      6  3048               8       1420
# Retail P          6739   4420     --   386            4420       1157
# MPG CITY          6874     73     18   779              73       1022
# MPG HWY           6675     61     25   661              61       1221
